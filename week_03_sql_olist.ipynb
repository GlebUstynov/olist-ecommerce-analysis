# %% [markdown]
# # Week 3 — SQL, Data Structure and Validation

# %%
import pandas as pd
from pathlib import Path

DATA_DIR = Path("data")

orders = pd.read_csv(DATA_DIR / "olist_orders_dataset.csv")
customers = pd.read_csv(DATA_DIR / "olist_customers_dataset.csv")
order_items = pd.read_csv(DATA_DIR / "olist_order_items_dataset.csv")
products = pd.read_csv(DATA_DIR / "olist_products_dataset.csv")
category_translation = pd.read_csv(
    DATA_DIR / "product_category_name_translation.csv"
)

tables = {
    "orders": orders,
    "customers": customers,
    "order_items": order_items,
    "products": products,
    "category_translation": category_translation
}

for table_name, df in tables.items():
    print(f"\n{table_name}: {df.shape}")
    print(df.columns.tolist())
# Out:
# orders: (99441, 8)
# ['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date']
#
# customers: (99441, 5)
# ['customer_id', 'customer_unique_id', 'customer_zip_code_prefix', 'customer_city', 'customer_state']
#
# order_items: (112650, 7)
# ['order_id', 'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date', 'price', 'freight_value']
#
# products: (32951, 9)
# ['product_id', 'product_category_name', 'product_name_lenght', 'product_description_lenght', 'product_photos_qty', 'product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm']
#
# category_translation: (71, 2)
# ['product_category_name', 'product_category_name_english']

# %%
def check_key(df, columns, table_name):
    unique_count = df.drop_duplicates(subset=columns).shape[0]
    duplicate_count = df.duplicated(subset=columns).sum()

    print(f"{table_name}")
    print(f"Key candidate: {columns}")
    print(f"Total rows: {len(df)}")
    print(f"Unique combinations: {unique_count}")
    print(f"Duplicates: {duplicate_count}")
    print("-" * 40)


check_key(orders, ["order_id"], "orders")
check_key(customers, ["customer_id"], "customers")
check_key(products, ["product_id"], "products")

check_key(
    category_translation,
    ["product_category_name"],
    "category_translation"
)

check_key(order_items, ["order_id"], "order_items: order_id only")

check_key(
    order_items,
    ["order_id", "order_item_id"],
    "order_items: composite key"
)
# Out:
# orders
# Key candidate: ['order_id']
# Total rows: 99441
# Unique combinations: 99441
# Duplicates: 0
# ----------------------------------------
# customers
# Key candidate: ['customer_id']
# Total rows: 99441
# Unique combinations: 99441
# Duplicates: 0
# ----------------------------------------
# products
# Key candidate: ['product_id']
# Total rows: 32951
# Unique combinations: 32951
# Duplicates: 0
# ----------------------------------------
# category_translation
# Key candidate: ['product_category_name']
# Total rows: 71
# Unique combinations: 71
# Duplicates: 0
# ----------------------------------------
# order_items: order_id only
# Key candidate: ['order_id']
# Total rows: 112650
# Unique combinations: 98666
# Duplicates: 13984
# ----------------------------------------
# order_items: composite key
# Key candidate: ['order_id', 'order_item_id']
# Total rows: 112650
# Unique combinations: 112650
# Duplicates: 0
# ----------------------------------------

# %%
print("Total rows:", len(order_items))

print(
    "Unique order_id:",
    order_items["order_id"].nunique()
)

print(
    "Repeated order_id rows:",
    order_items["order_id"].duplicated().sum()
)

print(
    "Duplicate order_id + order_item_id:",
    order_items.duplicated(
        subset=["order_id", "order_item_id"]
    ).sum()
)
# Out:
# Total rows: 112650
# Unique order_id: 98666
# Repeated order_id rows: 13984
# Duplicate order_id + order_item_id: 0
